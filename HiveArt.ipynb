# %%
import numpy as np
import pandas as pd
df=pd.read_csv('C:/Users/Harpreet/hiveart.csv')

df
# Out:
#       Account manager                          Client Name Date of Contact
# 0         Milan Crona              Wyman, Farrell and Haag      2015-10-31
# 1        Aidan Pouros           Veum, McClure and Schuster      2013-12-15
# 2        Aidan Pouros           Veum, McClure and Schuster      2013-12-07
# 3         Milan Crona                      Armstrong Group      2013-11-02
# 4        Aidan Pouros            Lueilwitz, Moore and Hahn      2013-12-25
# 5       Chauncey Dach                         Abbott Group      2016-03-21
# 6       Chauncey Dach        Oga, Gottlieb and Cruickshank      2013-10-27
# 7     Rigoberto White          Fahey, Wunsch and Bashirian      2016-05-14
# 8     Rigoberto White                          Bosco-Ortiz      2014-07-14
# 9     Rigoberto White                       Ondricka-Wolff      2015-10-14
# 10    Rigoberto White            Anderson, Kutch and Hyatt      2014-01-17
# ...

# %%
df.isnull().sum()
# Out:
# Account manager    0
# Client Name        0
# Date of Contact    0
# dtype: int64

# %%
df.describe()
# Out:
#        Account manager        Client Name Date of Contact
# count             1001               1001            1001
# unique               4                 35             704
# top        Milan Crona  Eichmann and Sons      2013-10-11
# freq               286                 38               7

# %%
df['Date of Contact']
# Out:
# 0       2015-10-31
# 1       2013-12-15
# 2       2013-12-07
# 3       2013-11-02
# 4       2013-12-25
# 5       2016-03-21
# 6       2013-10-27
# 7       2016-05-14
# 8       2014-07-14
# 9       2015-10-14
# 10      2014-01-17
# 11      2016-11-14
# 12      2015-10-17
# 13      2013-10-22
# 14      2014-09-23
# 15      2013-10-28
# 16      2015-10-06
# 17      2013-11-20
# 18      2015-02-04
# 19      2016-12-13
# 20      2015-10-30
# 21      2017-09-21
# 22      2013-10-16
# 23      2017-05-04
# 24      2013-10-24
# 25      2015-09-12
# 26      2014-07-04
# 27      2017-04-14
# 28      2015-10-25
# 29      2014-12-05
#            ...
# 971     2014-11-26
# 972     2016-10-11
# 973     2015-05-25
# 974     2014-08-23
# 975     2015-08-10
# 976     2016-11-01
# 977     2013-10-12
# 978     2014-11-14
# 979     2015-03-20
# 980     2017-04-24
# 981     2016-06-05
# 982     2015-07-06
# 983     2014-11-04
# 984     2016-04-05
# 985     2016-06-14
# 986     2016-09-02
# ...

# %%
df.sort_values('Date of Contact',ascending=True)
# Out:
#      Account manager                          Client Name Date of Contact
# 635  Rigoberto White        Medhurst, Ankunding and Wolff      2013-10-03
# 500  Rigoberto White          Fahey, Wunsch and Bashirian      2013-10-04
# 433    Chauncey Dach                    Donnelly-Champlin      2013-10-04
# 448      Milan Crona             Orn, Russel and O'Reilly      2013-10-04
# 37     Chauncey Dach                             Koss Inc      2013-10-05
# 251    Chauncey Dach                           Walter Inc      2013-10-05
# 744  Rigoberto White                     Sanford and Sons      2013-10-05
# 565      Milan Crona              Wyman, Farrell and Haag      2013-10-06
# 357     Aidan Pouros                          Hagenes Inc      2013-10-06
# 607     Aidan Pouros                         Abbott Group      2013-10-06
# 702    Chauncey Dach            Denesik, Stehr and Carter      2013-10-09
# 30       Milan Crona                        Halvorson LLC      2013-10-09
# ...

# %%
df['Date of Contact'].count()
# Out:
# 1001

# %%
a=df.groupby('Date of Contact').size()
print a
# Out:
# Date of Contact
# 2013-10-03    1
# 2013-10-04    3
# 2013-10-05    3
# 2013-10-06    3
# 2013-10-09    2
# 2013-10-10    2
# 2013-10-11    7
# 2013-10-12    3
# 2013-10-13    1
# 2013-10-14    1
# 2013-10-15    2
# 2013-10-16    1
# 2013-10-17    1
# 2013-10-18    4
# 2013-10-19    2
# 2013-10-20    2
# 2013-10-21    2
# 2013-10-22    4
# 2013-10-23    1
# 2013-10-24    2
# 2013-10-25    4
# 2013-10-26    1
# 2013-10-27    2
# 2013-10-28    1
# 2013-10-29    1
# 2013-10-30    2
# 2013-10-31    2
# 2013-11-01    1
# 2013-11-02    1
# 2013-11-03    1
#              ..
# 2017-08-15    1
# 2017-08-16    1
# 2017-08-18    1
# 2017-08-19    2
# 2017-08-22    1
# 2017-08-23    1
# 2017-08-28    1
# 2017-08-29    1
# 2017-08-30    1
# 2017-08-31    2
# 2017-09-02    1
# 2017-09-04    2
# 2017-09-07    3
# 2017-09-08    1
# 2017-09-09    1
# 2017-09-10    2
# 2017-09-11    1
# 2017-09-12    2
# 2017-09-13    1
# 2017-09-14    1
# 2017-09-15    1
# 2017-09-16    1
# 2017-09-17    1
# ...

# %%
b=df.groupby('Client Name').size()
print b
# Out:
# Client Name
# Abbott Group                           31
# Anderson, Kutch and Hyatt              24
# Armstrong Group                        25
# Bosco-Ortiz                            23
# Brown, Wyman and Grimes                35
# Cormier LLC                            24
# Denesik, Stehr and Carter              33
# Donnelly-Champlin                      35
# Eichmann and Sons                      38
# Fahey, Wunsch and Bashirian            34
# Franecki-Feil                          29
# Hagenes Inc                            23
# Halvorson LLC                          31
# Hauck Group                            20
# Hermiston, Armstrong and Balistreri    30
# Hoppe-Batz                             29
# Johnston-Schaden                       33
# Koss Inc                               24
# Kris, Shanahan and Quigley             29
# Kuhic, Stark and Kreiger               24
# Lemke-Pfannerstill                     28
# Lindgren, Graham and Spinka            28
# ...

# %%
df['Date of Contact']=pd.to_datetime(df['Date of Contact'])
df
# Out:
#       Account manager                          Client Name Date of Contact
# 0         Milan Crona              Wyman, Farrell and Haag      2015-10-31
# 1        Aidan Pouros           Veum, McClure and Schuster      2013-12-15
# 2        Aidan Pouros           Veum, McClure and Schuster      2013-12-07
# 3         Milan Crona                      Armstrong Group      2013-11-02
# 4        Aidan Pouros            Lueilwitz, Moore and Hahn      2013-12-25
# 5       Chauncey Dach                         Abbott Group      2016-03-21
# 6       Chauncey Dach        Oga, Gottlieb and Cruickshank      2013-10-27
# 7     Rigoberto White          Fahey, Wunsch and Bashirian      2016-05-14
# 8     Rigoberto White                          Bosco-Ortiz      2014-07-14
# 9     Rigoberto White                       Ondricka-Wolff      2015-10-14
# 10    Rigoberto White            Anderson, Kutch and Hyatt      2014-01-17
# ...

# %%
a=df.groupby(df['Date of Contact'].dt.strftime('%B'))['Client Name'].sum().sort_values().head()
print a
# Out:
# Date of Contact
# March       Abbott GroupArmstrong GroupVeum, McClure and S...
# January     Anderson, Kutch and HyattFranecki-FeilMitchell...
# November    Armstrong GroupMitchell and SonsJohnston-Schad...
# July        Bosco-OrtizKris, Shanahan and QuigleyHagenes I...
# June        Brown, Wyman and GrimesHauck GroupMedhurst, An...
# Name: Client Name, dtype: object
